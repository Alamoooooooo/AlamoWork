# %% [markdown]
# <a href="https://colab.research.google.com/github/Alamoooooooo/AlamoWork/blob/master/bc2abf40d0393360080f5f7f9869f92b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Amazon KDD Cup 2023 - Task 1 - Next Product Recommendation
#
# ![](https://images.aicrowd.com/raw_images/challenges/banner_file/1116/6c8fecd6d7c225b4ed11.jpg)
#
# This notebook will contains instructions and example submission with random predictions.

# %% [markdown]
# ## Installations 🤖
#
# 1. `aicrowd-cli` for downloading challenge data and making submissions
# 2. `pyarrow` for saving to parquet for submissions

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: alabaster==0.7.12 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (0.7.12)
# Requirement already satisfied: atomicwrites==1.3.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: attrs==19.3.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (19.3.0)
# Requirement already satisfied: Babel==2.8.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (2.8.0)
# Requirement already satisfied: bleach==3.1.4 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (3.1.4)
# Requirement already satisfied: certifi==2019.11.28 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (2019.11.28)
# Requirement already satisfied: chardet==3.0.4 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (3.0.4)
# Collecting Click==7.0
#   Using cached Click-7.0-py2.py3-none-any.whl (81 kB)
# Requirement already satisfied: coverage==5.0.2 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (5.0.2)
# Requirement already satisfied: docutils==0.15.2 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 10)) (0.15.2)
# Requirement already satisfied: emoji==0.5.4 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 11)) (0.5.4)
# Requirement already satisfied: entrypoints==0.3 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 12)) (0.3)
# Requirement already satisfied: filelock==3.0.12 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 13)) (3.0.12)
# Requirement already satisfied: flake8==3.7.9 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 14)) (3.7.9)
# Requirement already satisfied: flake8-docstrings==1.5.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 15)) (1.5.0)
# Requirement already satisfied: idna==2.8 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 16)) (2.8)
# Requirement already satisfied: imagesize==1.2.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 17)) (1.2.0)
# Requirement already satisfied: importlib-metadata==1.4.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 18)) (1.4.0)
# Requirement already satisfied: Jinja2==2.10.3 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 19)) (2.10.3)
# Requirement already satisfied: MarkupSafe==1.1.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 20)) (1.1.1)
# Requirement already satisfied: mccabe==0.6.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 21)) (0.6.1)
# Requirement already satisfied: more-itertools==8.1.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 22)) (8.1.0)
# Requirement already satisfied: packaging==20.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 23)) (20.0)
# Requirement already satisfied: pip-check-reqs==2.0.3 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 24)) (2.0.3)
# Requirement already satisfied: pip-licenses==1.18.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 25)) (1.18.0)
# Requirement already satisfied: pkginfo==1.5.0.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 26)) (1.5.0.1)
# Requirement already satisfied: pluggy==0.13.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 27)) (0.13.1)
# Requirement already satisfied: PTable==0.9.2 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 28)) (0.9.2)
# Requirement already satisfied: py==1.8.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 29)) (1.8.1)
# Requirement already satisfied: pycodestyle==2.5.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 30)) (2.5.0)
# Requirement already satisfied: pycryptodome==3.9.4 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 31)) (3.9.4)
# Requirement already satisfied: pydocstyle==5.0.2 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 32)) (5.0.2)
# Requirement already satisfied: pyflakes==2.1.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 33)) (2.1.1)
# Collecting Pygments==2.5.2
#   Using cached Pygments-2.5.2-py2.py3-none-any.whl (896 kB)
# Requirement already satisfied: pyparsing==2.4.6 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 35)) (2.4.6)
# Requirement already satisfied: pyperclip==1.7.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 36)) (1.7.0)
# Requirement already satisfied: pytest==3.10.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 37)) (3.10.1)
# Requirement already satisfied: pytest-cov==2.8.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 38)) (2.8.1)
# Requirement already satisfied: pytest-pythonpath==0.7.3 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 39)) (0.7.3)
# Requirement already satisfied: python-gitlab==1.15.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 40)) (1.15.0)
# Requirement already satisfied: pytz==2019.3 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 41)) (2019.3)
# Requirement already satisfied: PyYAML==5.3 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 42)) (5.3)
# Requirement already satisfied: readme-renderer==24.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 43)) (24.0)
# Collecting requests==2.22.0
#   Using cached requests-2.22.0-py2.py3-none-any.whl (57 kB)
# Requirement already satisfied: requests-toolbelt==0.9.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 45)) (0.9.1)
# Requirement already satisfied: shellescape==3.4.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 46)) (3.4.1)
# Requirement already satisfied: six==1.13.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 47)) (1.13.0)
# Requirement already satisfied: snowballstemmer==2.0.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 48)) (2.0.0)
# Requirement already satisfied: Sphinx==2.3.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 49)) (2.3.1)
# Requirement already satisfied: sphinx-rtd-theme==0.4.3 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 50)) (0.4.3)
# Requirement already satisfied: sphinxcontrib-applehelp==1.0.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 51)) (1.0.1)
# Requirement already satisfied: sphinxcontrib-devhelp==1.0.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 52)) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp==1.0.2 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 53)) (1.0.2)
# Requirement already satisfied: sphinxcontrib-jsmath==1.0.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 54)) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp==1.0.2 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 55)) (1.0.2)
# Requirement already satisfied: sphinxcontrib-serializinghtml==1.1.3 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 56)) (1.1.3)
# Requirement already satisfied: ssh-agent-setup==1.0.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 57)) (1.0.1)
# Collecting toml==0.10.0
#   Using cached toml-0.10.0-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: tox==3.14.3 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 59)) (3.14.3)
# Collecting tqdm==4.41.1
#   Using cached tqdm-4.41.1-py2.py3-none-any.whl (56 kB)
# Requirement already satisfied: twine==1.15.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 61)) (1.15.0)
# Requirement already satisfied: urllib3==1.25.7 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 62)) (1.25.7)
# Requirement already satisfied: virtualenv==16.7.9 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 63)) (16.7.9)
# Requirement already satisfied: webencodings==0.5.1 in /home/codespace/.local/lib/python3.10/site-packages (from -r requirements.txt (line 64)) (0.5.1)
# Requirement already satisfied: wget==3.2 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 65)) (3.2)
# Requirement already satisfied: zipp==0.6.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 66)) (0.6.0)
# Requirement already satisfied: yq==2.10.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from -r requirements.txt (line 67)) (2.10.0)
# Requirement already satisfied: pip>=10.0.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from pip-check-reqs==2.0.3->-r requirements.txt (line 24)) (23.0.1)
# Requirement already satisfied: setuptools in /home/codespace/.local/lib/python3.10/site-packages (from pytest==3.10.1->-r requirements.txt (line 37)) (67.6.0)
# Requirement already satisfied: argcomplete>=1.8.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from yq==2.10.0->-r requirements.txt (line 67)) (3.0.5)
# Requirement already satisfied: xmltodict>=0.11.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from yq==2.10.0->-r requirements.txt (line 67)) (0.13.0)
# Installing collected packages: toml, tqdm, requests, Pygments, Click
#   Attempting uninstall: toml
#     Found existing installation: toml 0.10.2
#     Uninstalling toml-0.10.2:
#       Successfully uninstalled toml-0.10.2
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.65.0
#     Uninstalling tqdm-4.65.0:
#       Successfully uninstalled tqdm-4.65.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.28.2
#     Uninstalling requests-2.28.2:
#       Successfully uninstalled requests-2.28.2
#   Attempting uninstall: Pygments
#     Found existing installation: Pygments 2.14.0
#     Uninstalling Pygments-2.14.0:
#       Successfully uninstalled Pygments-2.14.0
#   Attempting uninstall: Click
#     Found existing installation: click 7.1.2
#     Uninstalling click-7.1.2:
#       Successfully uninstalled click-7.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# nbconvert 7.2.9 requires jinja2>=3.0, but you have jinja2 2.10.3 which is incompatible.
# nbconvert 7.2.9 requires markupsafe>=2.0, but you have markupsafe 1.1.1 which is incompatible.
# jupyterlab-server 2.20.0 requires babel>=2.10, but you have babel 2.8.0 which is incompatible.
# jupyterlab-server 2.20.0 requires jinja2>=3.0.3, but you have jinja2 2.10.3 which is incompatible.
# jupyterlab-server 2.20.0 requires packaging>=21.3, but you have packaging 20.0 which is incompatible.
# jupyterlab-server 2.20.0 requires requests>=2.28, but you have requests 2.22.0 which is incompatible.
# jupyter-server 2.4.0 requires pyzmq>=24, but you have pyzmq 22.1.0 which is incompatible.
# rich 10.16.2 requires pygments<3.0.0,>=2.6.0, but you have pygments 2.5.2 which is incompatible.
# aicrowd-cli 0.1.15 requires click<8,>=7.1.2, but you have click 7.0 which is incompatible.
# aicrowd-cli 0.1.15 requires requests<3,>=2.25.1, but you have requests 2.22.0 which is incompatible.
# aicrowd-cli 0.1.15 requires toml<1,>=0.10.2, but you have toml 0.10.0 which is incompatible.
# aicrowd-cli 0.1.15 requires tqdm<5,>=4.56.0, but you have tqdm 4.41.1 which is incompatible.
# Successfully installed Click-7.0 Pygments-2.5.2 requests-2.22.0 toml-0.10.0 tqdm-4.41.1

# %%
# !pip install aicrowd-cli pyarrow
# Out:
# Requirement already satisfied: aicrowd-cli in /usr/local/python/3.10.4/lib/python3.10/site-packages (0.1.15)
# Requirement already satisfied: pyarrow in /usr/local/python/3.10.4/lib/python3.10/site-packages (11.0.0)
# Requirement already satisfied: requests-toolbelt<1,>=0.9.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from aicrowd-cli) (0.9.1)
# Collecting click<8,>=7.1.2
#   Using cached click-7.1.2-py2.py3-none-any.whl (82 kB)
# Requirement already satisfied: pyzmq==22.1.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from aicrowd-cli) (22.1.0)
# Requirement already satisfied: rich<11,>=10.0.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from aicrowd-cli) (10.16.2)
# Requirement already satisfied: python-slugify<6,>=5.0.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from aicrowd-cli) (5.0.2)
# Requirement already satisfied: semver<3,>=2.13.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from aicrowd-cli) (2.13.0)
# Requirement already satisfied: GitPython==3.1.18 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from aicrowd-cli) (3.1.18)
# Collecting toml<1,>=0.10.2
#   Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Collecting tqdm<5,>=4.56.0
#   Using cached tqdm-4.65.0-py3-none-any.whl (77 kB)
# Collecting requests<3,>=2.25.1
#   Using cached requests-2.28.2-py3-none-any.whl (62 kB)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from GitPython==3.1.18->aicrowd-cli) (4.0.10)
# Requirement already satisfied: numpy>=1.16.6 in /home/codespace/.local/lib/python3.10/site-packages (from pyarrow) (1.24.2)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from python-slugify<6,>=5.0.0->aicrowd-cli) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3,>=2.25.1->aicrowd-cli) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from requests<3,>=2.25.1->aicrowd-cli) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from requests<3,>=2.25.1->aicrowd-cli) (2019.11.28)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from requests<3,>=2.25.1->aicrowd-cli) (1.25.7)
# Requirement already satisfied: colorama<0.5.0,>=0.4.0 in /home/codespace/.local/lib/python3.10/site-packages (from rich<11,>=10.0.0->aicrowd-cli) (0.4.6)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from rich<11,>=10.0.0->aicrowd-cli) (0.9.1)
# Collecting pygments<3.0.0,>=2.6.0
#   Using cached Pygments-2.14.0-py3-none-any.whl (1.1 MB)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->GitPython==3.1.18->aicrowd-cli) (5.0.0)
# Installing collected packages: tqdm, toml, requests, pygments, click
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.41.1
#     Uninstalling tqdm-4.41.1:
#       Successfully uninstalled tqdm-4.41.1
#   Attempting uninstall: toml
#     Found existing installation: toml 0.10.0
#     Uninstalling toml-0.10.0:
#       Successfully uninstalled toml-0.10.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.22.0
#     Uninstalling requests-2.22.0:
#       Successfully uninstalled requests-2.22.0
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.5.2
#     Uninstalling Pygments-2.5.2:
#       Successfully uninstalled Pygments-2.5.2
#   Attempting uninstall: click
#     Found existing installation: Click 7.0
#     Uninstalling Click-7.0:
#       Successfully uninstalled Click-7.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# nbconvert 7.2.9 requires jinja2>=3.0, but you have jinja2 2.10.3 which is incompatible.
# nbconvert 7.2.9 requires markupsafe>=2.0, but you have markupsafe 1.1.1 which is incompatible.
# jupyterlab-server 2.20.0 requires babel>=2.10, but you have babel 2.8.0 which is incompatible.
# jupyterlab-server 2.20.0 requires jinja2>=3.0.3, but you have jinja2 2.10.3 which is incompatible.
# jupyterlab-server 2.20.0 requires packaging>=21.3, but you have packaging 20.0 which is incompatible.
# jupyter-server 2.4.0 requires pyzmq>=24, but you have pyzmq 22.1.0 which is incompatible.
# Successfully installed click-7.1.2 pygments-2.14.0 requests-2.28.2 toml-0.10.2 tqdm-4.65.0

# %% [markdown]
# ## Login to AIcrowd and download the data 📚

# %%
# !aicrowd login
# Out:
# Please login here: https://api.aicrowd.com/auth/roghsVupx9VgR6HfqYSjXKEYmTP0uToaGHcXOHQuMz0
# API Key valid
# Gitlab access token valid
# Saved details successfully!

# %%
# !aicrowd dataset download --challenge task-1-next-product-recommendation
# Out:
# sessions_test_task1.csv: 100%|█████████████| 19.4M/19.4M [00:02<00:00, 8.54MB/s]
# sessions_test_task2.csv: 100%|█████████████| 1.92M/1.92M [00:01<00:00, 1.61MB/s]
# sessions_test_task3.csv: 100%|█████████████| 2.67M/2.67M [00:01<00:00, 2.10MB/s]
# products_train.csv: 100%|████████████████████| 589M/589M [00:38<00:00, 15.1MB/s]
# sessions_train.csv: 100%|████████████████████| 259M/259M [00:17<00:00, 14.8MB/s]

# %% [markdown]
# ## Setup data and task information

# %%
import os
import numpy as np
import pandas as pd
from functools import lru_cache

# %%
train_data_dir = '.'
test_data_dir = '.'
task = 'task1'
PREDS_PER_SESSION = 100

# %%
# Cache loading of data for multiple calls

@lru_cache(maxsize=1)
def read_product_data():
    return pd.read_csv(os.path.join(train_data_dir, 'products_train.csv'))

@lru_cache(maxsize=1)
def read_train_data():
    return pd.read_csv(os.path.join(train_data_dir, 'sessions_train.csv'))

@lru_cache(maxsize=3)
def read_test_data(task):
    return pd.read_csv(os.path.join(test_data_dir, f'sessions_test_{task}.csv'))

# %% [markdown]
# ## Data Description
#
# The Multilingual Shopping Session Dataset is a collection of **anonymized customer sessions** containing products from six different locales, namely English, German, Japanese, French, Italian, and Spanish. It consists of two main components: **user sessions** and **product attributes**. User sessions are a list of products that a user has engaged with in chronological order, while product attributes include various details like product title, price in local currency, brand, color, and description.
#
# ---
#
# ### Each product as its associated information:
#
#
# **locale**: the locale code of the product (e.g., DE)
#
# **id**: a unique for the product. Also known as Amazon Standard Item Number (ASIN) (e.g., B07WSY3MG8)
#
# **title**: title of the item (e.g., “Japanese Aesthetic Sakura Flowers Vaporwave Soft Grunge Gift T-Shirt”)
#
# **price**: price of the item in local currency (e.g., 24.99)
#
# **brand**: item brand name (e.g., “Japanese Aesthetic Flowers & Vaporwave Clothing”)
#
# **color**: color of the item (e.g., “Black”)
#
# **size**: size of the item (e.g., “xxl”)
#
# **model**: model of the item (e.g., “iphone 13”)
#
# **material**: material of the item (e.g., “cotton”)
#
# **author**: author of the item (e.g., “J. K. Rowling”)
#
# **desc**: description about a item’s key features and benefits called out via bullet points (e.g., “Solid colors: 100% Cotton; Heather Grey: 90% Cotton, 10% Polyester; All Other Heathers …”)

# %% [markdown]
# ## EDA 💽

# %%
def read_locale_data(locale, task):
    products = read_product_data().query(f'locale == "{locale}"')
    sess_train = read_train_data().query(f'locale == "{locale}"')
    sess_test = read_test_data(task).query(f'locale == "{locale}"')
    return products, sess_train, sess_test

def show_locale_info(locale, task):
    products, sess_train, sess_test = read_locale_data(locale, task)

    train_l = sess_train['prev_items'].apply(lambda sess: len(sess))
    test_l = sess_test['prev_items'].apply(lambda sess: len(sess))

    print(f"Locale: {locale} \n"
          f"Number of products: {products['id'].nunique()} \n"
          f"Number of train sessions: {len(sess_train)} \n"
          f"Train session lengths - "
          f"Mean: {train_l.mean():.2f} | Median {train_l.median():.2f} | "
          f"Min: {train_l.min():.2f} | Max {train_l.max():.2f} \n"
          f"Number of test sessions: {len(sess_test)}"
        )
    if len(sess_test) > 0:
        print(
             f"Test session lengths - "
            f"Mean: {test_l.mean():.2f} | Median {test_l.median():.2f} | "
            f"Min: {test_l.min():.2f} | Max {test_l.max():.2f} \n"
        )
    print("======================================================================== \n")

# %%
products = read_product_data()
locale_names = products['locale'].unique()
for locale in locale_names:
    show_locale_info(locale, task)
# Out:
# Canceled future for execute_request message before replies were done
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
products.sample(5)
# Out:
#                  id locale                                              title  \
# 1535876  B08B3QTXJZ     IT  kwmobile Custodia Compatibile con Apple iPhone...
# 1198060  B0B2KN1Q6M     UK   Me To You Bear Sister Just For You Birthday Card
# 1024050  B099W7JSMT     UK  Syhood 32.8 Feet Christmas Metallic Tinsel Twi...
# 895070   B0BCG44MBT     JP  ラップタオル大人用 速乾大きいサイズ 風呂用サウナ 着るバスシャワー超吸水水泳 温泉湯浴み着...
# 1084330  B007E9VUQS     UK  Smiffys Make-Up FX Face and Body Paint, 16 ml ...
#
#            price          brand            color      size             model  \
# 1535876     8.49    KW-Commerce  blu chiaro matt       NaN  49982.58_m000813
# 1198060     2.99  Carte Blanche              NaN       NaN               NaN
# 1024050     8.99         Syhood             Blue       NaN               NaN
# 895070   1589.00        OTTCFRN              ピンク     ワンサイズ               NaN
# 1084330     2.94       Smiffy's     Brown (dark)  One Size             39184
#
#          material author                                               desc
# 1535876  Silicone    NaN  ANTI URTO: i bordi rialzati della copertina pr...
# 1198060       NaN    NaN                                                NaN
# 1024050     Metal    NaN  Christmas style decor: the Christmas metallic ...
# 895070     ポリエステル    NaN  3 Dトリミング設計、（非ベルクロデザイン）よりユーザーフレンドリーで、使用時に音が出ず、肌...
# 1084330       NaN    NaN               Add colour to your dress-up costume!

# %%
train_sessions = read_train_data()
train_sessions.sample(5)
# Out:
#                                                 prev_items   next_item locale
# 2994683  ['B07T3GN2VH' 'B07T2FDFKZ' 'B07T3DJMT5' 'B098T...  B07ZJZNRMP     UK
# 190907   ['B07ZRN33PQ' 'B07ZRMCRG7' 'B09C24TXP4' 'B09C2...  B091G94JDR     DE
# 3595388  ['B09BJNQRNZ' 'B08XK8M5Z3' 'B09DPD5QJ8' 'B09KN...  B0B4RYT3ZS     IT
# 465436            ['B07GXQCFXK' 'B07GXQD5Y3' 'B00E6722OK']  B00D3HZYGW     DE
# 3518477  ['B09ZY6WYJX' 'B0B85CSNXW' 'B09ZY6WYJX' 'B0B85...  B083DRSWKR     IT

# %%
test_sessions = read_test_data(task)
test_sessions.sample(5)
# Out:
#                                                prev_items locale
# 202046  ['B08H95Y452' 'B0BG3GRMF9' 'B0BG3GRMF9' 'B0BF5...     UK
# 98284            ['B09RQ8T72D' 'B09998MBFM' 'B09RQ8T72D']     DE
# 191260           ['B0871Z739B' 'B09N92NHGR' 'B0871Z739B']     JP
# 113547           ['B0B56Q2VXW' 'B0B56NPJ4G' 'B0B56Q2VXW']     JP
# 102804  ['B08G97TPH8' 'B08G91WFQR' 'B08G93D8LZ' 'B082P...     DE

# %% [markdown]
# ## Generate Submission 🏋️‍♀️
#
#
#
# Submission format:
# 1. The submission should be a **parquet** file with the sessions from all the locales.
# 2. Predicted products ids per locale should only be a valid product id of that locale.
# 3. Predictions should be added in new column named **"next_item_prediction"**.
# 4. Predictions should be a list of string id values

# %%
def random_predicitons(locale, sess_test_locale):
    random_state = np.random.RandomState(42)
    products = read_product_data().query(f'locale == "{locale}"')
    predictions = []
    for _ in range(len(sess_test_locale)):
        predictions.append(
            list(products['id'].sample(PREDS_PER_SESSION, replace=True, random_state=random_state))
        ) 
    sess_test_locale['next_item_prediction'] = predictions
    sess_test_locale.drop('prev_items', inplace=True, axis=1)
    return sess_test_locale

# %%
test_sessions = read_test_data(task)
predictions = []
test_locale_names = test_sessions['locale'].unique()
for locale in test_locale_names:
    sess_test_locale = test_sessions.query(f'locale == "{locale}"').copy()
    predictions.append(
        random_predicitons(locale, sess_test_locale)
    )
predictions = pd.concat(predictions).reset_index(drop=True)
predictions.sample(5)
# Out:
#        locale                               next_item_prediction
# 197622     JP  [B0B3JKGTBH, B07WFD1L1R, B0B1N2FMMG, B0BLJSMWJ...
# 108611     JP  [B07WV5GXPB, B0B7DS3HQL, B0866HDFTS, B009GQYDX...
# 284074     UK  [B09BB5SPR3, B0816CXMSZ, B08JV76967, B08MW68KC...
# 34652      DE  [B007H6POYW, B08M5GZGFT, B08JQZMFL7, B0BKP9BSL...
# 268639     UK  [B06XCGCKG7, B0B9NXKN54, B091YX63K7, B00Z65X1G...

# %% [markdown]
# # Validate predictions ✅

# %%
def check_predictions(predictions, check_products=False):
    """
    These tests need to pass as they will also be applied on the evaluator
    """
    test_locale_names = test_sessions['locale'].unique()
    for locale in test_locale_names:
        sess_test = test_sessions.query(f'locale == "{locale}"')
        preds_locale =  predictions[predictions['locale'] == sess_test['locale'].iloc[0]]
        assert sorted(preds_locale.index.values) == sorted(sess_test.index.values), f"Session ids of {locale} doesn't match"

        if check_products:
            # This check is not done on the evaluator
            # but you can run it to verify there is no mixing of products between locales
            # Since the ground truth next item will always belong to the same locale
            # Warning - This can be slow to run
            products = read_product_data().query(f'locale == "{locale}"')
            predicted_products = np.unique( np.array(list(preds_locale["next_item_prediction"].values)) )
            assert np.all( np.isin(predicted_products, products['id']) ), f"Invalid products in {locale} predictions"

# %%
check_predictions(predictions)

# %%
# Its important that the parquet file you submit is saved with pyarrow backend
predictions.to_parquet(f'submission_{task}.parquet', engine='pyarrow')

# %% [markdown]
# ## Submit to AIcrowd 🚀

# %%
# You can submit with aicrowd-cli, or upload manually on the challenge page.
# !aicrowd submission create -c task-1-next-product-recommendation -f "submission_task1.parquet"
